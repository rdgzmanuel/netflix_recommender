# %%
import pandas as pd
import re

# %%
df = pd.read_csv("netflix1.csv")
df["Punctuation"] = 0
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
run = True
while run:
    last_seen_title = input("Enter the title of the last film you've seen: ")
    try:
        last_seen = df.loc[df["title"] == last_seen_title]
        product = last_seen.iloc[0, 1]
        director = last_seen.iloc[0, 3]
        country = last_seen.iloc[0, 4]
        date_added = last_seen.iloc[0, 5]
        listed_in = last_seen.iloc[0, 9]
        run = False
    except:
        print("Film not found!!!")
matches = [0 for i in range(len(df))]

for index, row in df.iterrows():
    if re.findall(country, row["country"]) != []:
        matches[index] += 2
    if re.findall(director, row["director"]) != []:
        matches[index] += 10
    if re.findall(date_added, row["date_added"]) != []:
        matches[index] += 3
    if re.findall(listed_in, row["listed_in"]) != []:
        matches[index] += 8

df["Punctuation"] += matches
df_sorted = df.sort_values('Punctuation', ascending = False)

df_sorted.head()

recommended_df = df_sorted.iloc[1:10]    # Seleccionamos las 10 con mejor puntuación

print("You could try the following movies: ")
print(recommended_df.title)
# Out:
# Enter the title of the last film you've seen:  The Lord of the Rings
# Film not found!!!
# Enter the title of the last film you've seen:  Zak Storm
# You could try the following movies:
# 8789                                              YOM
# 8193                     All Hail King Julien: Exiled
# 98                                       Centaurworld
# 297                                Pokémon the Series
# 299     Barbie Dreamhouse Adventures: Go Team Roberts
# 300                        Archibald's Next Big Thing
# 301              Calico Critters Mini Episodes Clover
# 306               Chhota Bheem Kung Fu Dhamaka Series
# 8192                                        Miniforce
# Name: title, dtype: object

# %%
# product = film_series.iloc[0, 1]
# director = film_series.iloc[0, 3]
# country = film_series.iloc[0, 4]
# date_added = film_series.iloc[0, 5]
# release_years = film_series.iloc[0, 6]



#df = utility(df, film_series)
